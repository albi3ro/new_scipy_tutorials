# %% [markdown]
# # SciPy Optimize
# ## Test Functions
#
# A variety of functions, such as those listed on [Wikipedia](https://en.wikipedia.org/wiki/Test_functions_for_optimization) or [https://www.sfu.ca/~ssurjano/optimization.html](https://www.sfu.ca/~ssurjano/optimization.html) provide functions that test algorithm efficiency.

# %%
# Importing the packages for the example
import numpy as np
import scipy.optimize as optimize
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot_surface(x0_a, x1_a, optimize.rosen([x0_a,x1_a]))
ax.view_init(30, 80)
ax.set_zlim([0,5000])
ax.set_xlim([-3,3])

plt.show()

# %%
optimize.minimize(optimize.rosen,[2,2])
# Out:
#       fun: 1.8932893809017893e-11
#  hess_inv: array([[0.51675994, 1.03186494],
#        [1.03186494, 2.0655726 ]])
#       jac: array([ 5.27380711e-06, -2.50575298e-06])
#   message: 'Optimization terminated successfully.'
#      nfev: 140
#       nit: 30
#      njev: 35
#    status: 0
#   success: True
#         x: array([0.99999565, 0.99999129])
